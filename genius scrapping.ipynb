# %% [markdown]
# # 1 - Scrapping french rap lyrics from genius
#
# We use wikipedia to find a list of ~450 famous french rapper, then we scrap each artist song catalog to copy all their lyrics
# in a text file.
#
# - The model training was run on google cloud, so we use google drive to host google collab file.

# %%
# Make HTTP requests
import requests
# Scrape data from an HTML document
from bs4 import BeautifulSoup
# I/O
import os
# Search and manipulate strings
import re

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/MyDrive/ProjetDL") 
# !ls
# Out:
#  artistes.txt   lyrics	 model20   my_model  'Rap Generator V0.ipynb'

# %%
GENIUS_API_TOKEN = "YOUR_GENIUS_API_TOKEN"

# %%
# Get artist object from Genius API
def request_artist_info(artist_name, page, TOKEN = GENIUS_API_TOKEN):
    base_url = 'https://api.genius.com'
    headers = {'Authorization': 'Bearer ' + TOKEN}
    search_url = base_url + '/search?per_page=50&page=' + str(page)
    data = {'q': artist_name}
    #print(search_url)
    response = requests.get(search_url, data=data, headers=headers, timeout=5)
    return response

# Get Genius.com song url's from artist object
def request_song_url(artist_name, song_cap, TOKEN = GENIUS_API_TOKEN):
    page = 1
    songs = []
    
    while True:
        response = request_artist_info(artist_name, page, TOKEN)
        json = response.json()
        # Collect up to song_cap song objects from artist
        song_info = []
        for hit in json['response']['hits']:
            if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
                song_info.append(hit)
    
        # Collect song URL's from song objects
        for song in song_info:
            if (len(songs) < song_cap):
                url = song['result']['url']
                songs.append(url)
            
        if (len(songs) == song_cap):
            break
        #print(len(json['response']['hits']),len(song_info))
        if (len(song_info) < 5):
            break
        else:
            page += 1
        
    print('Found {} songs by {}'.format(len(songs), artist_name))
    return songs
    
# DEMO
request_song_url('JuL', 200, TOKEN = GENIUS_API_TOKEN_Etienne)
# Out:
# Found 200 songs by JuL
# ['https://genius.com/Julia-michaels-issues-lyrics',
#  'https://genius.com/Jul-joublie-tout-lyrics',
#  'https://genius.com/Jul-tchikita-lyrics',
#  'https://genius.com/Jul-tu-la-love-lyrics',
#  'https://genius.com/Olivia-rodrigo-and-julia-lester-wondering-lyrics',
#  'https://genius.com/Jul-dans-ma-paranoia-lyrics',
#  'https://genius.com/Julia-michaels-heaven-lyrics',
#  'https://genius.com/Julia-michaels-anxiety-lyrics',
#  'https://genius.com/Jul-my-world-lyrics',
#  'https://genius.com/Jul-wesh-alors-lyrics',
#  'https://genius.com/Alan-walker-digital-farm-animals-noah-cyrus-and-juliander-all-falls-down-lyrics',
#  'https://genius.com/Jul-lova-lyrics',
#  'https://genius.com/Jul-sors-le-cross-vole-lyrics',
#  'https://genius.com/Jul-comme-dhab-lyrics',
#  'https://genius.com/Jul-dans-mon-del-lyrics',
#  'https://genius.com/Jul-tout-seul-lyrics',
#  'https://genius.com/Jul-en-y-lyrics',
#  'https://genius.com/Jul-au-quartier-lyrics',
#  'https://genius.com/Jul-toto-et-ninetta-lyrics',
#  'https://genius.com/Jul-amnesia-lyrics',
#  'https://genius.com/Jul-mon-bijou-lyrics',
#  'https://genius.com/Julia-michaels-jump-lyrics',
#  'https://genius.com/Jul-mon-amour-lyrics',
#  'https://genius.com/Julia-zahra-just-an-illusion-lyrics',
#  'https://genius.com/Jul-le-sang-lyrics',
#  'https://genius.com/Julie-andrews-my-favorite-things-lyrics',
#  'https://genius.com/Jul-ils-sont-jaloux-lyrics',
#  'https://genius.com/Jul-mama-lyrics',
#  'https://genius.com/Jul-ma-jolie-lyrics',
#  'https://genius.com/Jul-encore-des-paroles-lyrics',
#  'https://genius.com/Jul-malade-lyrics',
#  'https://genius.com/Jul-tes-pas-le-seul-lyrics',
#  'https://genius.com/Jul-on-mappelle-lovni-lyrics',
#  'https://genius.com/Jul-pourquoi-tu-me-fais-le-gros-lyrics',
#  'https://genius.com/Jul-briganter-lyrics',
#  'https://genius.com/Julia-michaels-what-a-time-lyrics',
#  'https://genius.com/Angus-and-julia-stone-big-jet-plane-lyrics',
#  'https://genius.com/Jul-senora-lyrics',
#  'https://genius.com/Jul-la-classe-lyrics',
#  'https://genius.com/Jul-coucou-lyrics',
#  'https://genius.com/Jul-merce-quest-ce-qui-se-passe-lyrics',
#  'https://genius.com/Jul-lady-lyrics',
#  'https://genius.com/Juliensblog-11-september-lyrics',
#  'https://genius.com/Julie-and-the-phantoms-cast-bright-lyrics',
#  'https://genius.com/Julie-and-the-phantoms-cast-unsaid-emily-lyrics',
#  'https://genius.com/Julien-baker-sprained-ankle-lyrics',
#  'https://genius.com/Jul-oubliez-moi-lyrics',
#  'https://genius.com/Jul-elle-et-lautre-lyrics',
#  'https://genius.com/Jul-la-fusee-lyrics',
#  'https://genius.com/Jul-anti-bdh-lyrics',
#  'https://genius.com/Julien-baker-appointments-lyrics',
#  'https://genius.com/Julian-tuwim-wiersz-w-ktorym-autor-grzecznie-ale-stanowczo-uprasza-liczne-zastepy-bliznich-aby-go-w-dupe-pocaowali-annotated',
#  'https://genius.com/Jul-jeune-de-cite-lyrics',
#  'https://genius.com/Jul-mamasita-lyrics',
#  'https://genius.com/Jul-dans-la-legende-lyrics',
#  'https://genius.com/Julia-engelmann-stille-wasser-sind-attraktiv-annotated',
#  'https://genius.com/Jul-cest-trop-lyrics',
#  'https://genius.com/Julia-michaels-worst-in-me-lyrics',
#  'https://genius.com/Angus-and-julia-stone-chateau-lyrics',
#  'https://genius.com/Jul-grille-lyrics',
#  'https://genius.com/Julie-and-the-phantoms-cast-edge-of-great-lyrics',
#  'https://genius.com/Jul-on-est-trop-lyrics',
#  'https://genius.com/Lany-and-julia-michaels-okay-lyrics',
#  'https://genius.com/Jul-je-vais-toublier-lyrics',
#  'https://genius.com/Jul-elle-te-balade-lyrics',
#  'https://genius.com/Julien-baker-something-lyrics',
#  'https://genius.com/Jul-dans-mon-coeur-lyrics',
#  'https://genius.com/Julien-baker-rejoice-lyrics',
#  'https://genius.com/Jules-leblanc-photograph-lyrics',
#  'https://genius.com/Julie-andrews-the-sound-of-music-1994-lyrics',
#  'https://genius.com/Jul-dans-lappart-lyrics',
#  'https://genius.com/Jul-winners-lyrics',
#  'https://genius.com/Julien-baker-go-home-lyrics',
#  'https://genius.com/Jul-emotions-lyrics',
#  'https://genius.com/Jul-je-peux-pas-lyrics',
#  'https://genius.com/Jul-mon-reve-lyrics',
#  'https://genius.com/Jul-goodbye-lyrics',
#  'https://genius.com/Julie-and-the-phantoms-cast
#  'https://genius.com/Jul-gros-lyrics',
#  'https://genius.com/Jul-je-trouve-pas-le-sommeil-lyrics',
#  'https://genius.com/Julia-michaels-deep-lyrics',
#  'https://genius.com/Jul-ailleurs-lyrics',
#  'https://genius.com/Jul-nimporte-quoi-lyrics',
#  'https://genius.com/Jules-leblanc-little-things-lyrics',
#  'https://genius.com/Jul-allez-le-sang-lyrics',
#  'https://genius.com/Frenna-boef-and-dj-madam-julie-speciaal-lyrics',
#  'https://genius.com/Juliensblog-mammutmix-lyrics',
#  'https://genius.com/Julien-baker-sour-breath-lyrics',
#  'https://genius.com/Jul-vis-mon-malheur-lyrics',
#  'https://genius.com/Jul-cest-le-son-de-la-gratte-lyrics',
#  'https://genius.com/Jul-pim-pom-lyrics',
#  'https://genius.com/Julien-baker-good-news-lyrics',
#  'https://genius.com/Jul-chapeau-de-paille-lyrics',
#  'https://genius.com/Jul-jcvd-lyrics',
#  'https://genius.com/Jul-audi-volee-lyrics',
#  'https://genius.com/Jul-amigo-lyrics',
#  'https://genius.com/Jul-la-gachette-lyrics',
#  'https://genius.com/Jul-inspi-dailleurs-lyrics',
#  'https://genius.com/Jul-problemes-lyrics',
#  'https://genius.com/Jul-cest-pas-beau-lyrics',
#  'https://genius.com/Jul-coup-de-foudre-lyrics',
#  'https://genius.com/Julia-engelmann-one-day-reckoning-song-annotated',
#  'https://genius.com/Jul-tel-me-lyrics',
#  'https://genius.com/Jul-perdu-lyrics',
#  'https://genius.com/Jul-ca-me-degoute-lyrics',
#  'https://genius.com/Jul-la-galere-lyrics',
#  'https://genius.com/Jul-rien-a-cirer-lyrics',
#  'https://genius.com/Jul-comme-les-gens-dici-lyrics',
#  'https://genius.com/Juliette-armanet-je-te-sens-venir-lyrics',
#  'https://genius.com/Juliensblog-analyse-lyrics',
#  'https://genius.com/Julien-baker-blacktop-lyrics',
#  'https://genius.com/Jul-poto-ou-tes-lyrics',
#  'https://genius.com/Jul-jattends-lyrics',
#  'https://genius.com/Jul-1er-dans-la-bataille-lyrics',
#  'https://genius.com/Julia-michaels-into-you-lyrics',
#  'https://genius.com/Jul-tokyo-lyrics',
#  'https://genius.com/Jules-leblanc-dancing-on-the-ceiling-lyrics',
#  'https://genius.com/Jul-imagine-lyrics',
#  'https://genius.com/Julie-bergan-arigato-lyrics',
#  'https://genius.com/Julien-baker-hurt-less-lyrics',
#  'https://genius.com/Julien-baker-shadowboxing-lyrics',
#  'https://genius.com/Jul-de-retour-lyrics',
#  'https://genius.com/Jul-la-bandite-lyrics',
#  'https://genius.com/Jul-henrico-lyrics',
#  'https://genius.com/Jules-leblanc-somebodys-heart-lyrics',
#  'https://genius.com/Jul-dans-ma-cite-lyrics',
#  'https://genius.com/Jul-jai-fini-seul-lyrics',
#  'https://genius.com/Julinho-ksd-sentimento-safari-lyrics',
#  'https://genius.com/Jul-ca-vient-de-la-lyrics',
#  'https://genius.com/Jul-je-fais-ma-vie-lyrics',
#  'https://genius.com/Jul-il-me-faut-des-billets-lyrics',
#  'https://genius.com/Jul-pour-les-vaillants-lyrics',
#  'https://genius.com/Jul-ma-che-beaute-lyrics',
#  'https://genius.com/Jul-ce-que-je-vois-lyrics',
#  'https://genius.com/Jul-marseille-lyrics',
#  'https://genius.com/Jul-cest-ca-que-je-te-reproche-lyrics',
#  'https://genius.com/Julien-baker-happy-to-be-here-lyrics',
#  'https://genius.com/Julia-michaels-apple-lyrics',
#  'https://genius.com/Jul-en-place-lyrics',
#  'https://genius.com/Jul-madame-lyrics',
#  'https://genius.com/Julia-holter-feel-you-lyrics',
#  'https://genius.com/Jul-lacrizeomic-2-lyrics',
#  'https://genius.com/Julia-michaels-dont-wanna-think-lyrics',
#  'https://genius.com/Jul-nique-le-lyrics',
#  'https://genius.com/Julia-jacklin-pool-party-lyrics',
#  'https://genius.com/Angus-and-julia-stone-santa-monica-dream-lyrics',
#  'https://genius.com/Julien-baker-brittle-boned-lyrics',
#  'https://genius.com/Jul-je-men-fous-de-ta-nana-lyrics',
#  'https://genius.com/Jul-je-me-jette-a-leau-lyrics']

# %%
# Scrape lyrics from a Genius.com song URL
def scrape_song_lyrics(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    try:
        lyrics = soup.select_one('div[class^="Lyrics__Container"], .lyrics').get_text(strip=True, separator='\n')
    except:
        print("scrapping error for the song")

    #remove identifiers like chorus, verse, etc
    lyrics = re.sub(r'[\(\[].*?[\)\]]', '', lyrics)
    #remove empty lines
    lyrics = os.linesep.join([s for s in lyrics.splitlines() if s])         
    return lyrics
    
# DEMO
print(scrape_song_lyrics('https://genius.com/Damso-mosaique-solitaire-lyrics'))
# Out:
# Me d'mandez pas c'que j'fais dans la vie
# C'est si noir, vous s'rez pris de panique
# Quelque part, loin de toute compagnie
# Batterie Faible m'a fait perdre beaucoup d'amis
# Me serre pas la main, fais-moi un #Vie
# J'attends la mort comme en Gethsémani
# Baise-la c'est tout sinon elle f'ra des manies
# Elle manquera d'respect à ta famille
# Une seule erreur et t'as plus d'followers
# Donc j'fais c'que j'aime non pas c'que l'on me dit
# J'suis toujours debout, aux tombées des nuits
# Vu du ciel, l'Enfer est comme le Paradis
# "Crève dans ta merde, t'auras pas un radis"
# C'est à peu près ce que le daron m'a dit
# Heureusement gros culs ont su consoler
# De leurs 'ttes-cha, j'me suis empoisonné
# J'ai picolé, j'ai bu oui, j'ai bu oui
# J'perds la raison à cause de mes torts
# C'est ça qu'ça fait d'toujours bosser la nuit
# J'fume de trop, j'fais plus de sport
# "C'est pas très bon", m'a dit coach Elie
# Drogue dans la soute, à peine j'atterris
# J'roule un doobie, oh oui
# Ils ne me veulent pas du bien, no
# Ils ne me veulent pas du bien, no
# Ils font bonhomme de neige
# J'ai fait bonhomme de chemin
# Ils ne me veulent pas du bien, no
# Ils ne me veulent pas du bien, no
# J'suis sorti de la dèch'
# Vie en rose comme schneck de tchoin
# Fiancé à la vulgarité
# J'ai renoncé à la précarité
# J'ai mis mes chances dans le barillet
# J'ai tiré sans jamais m'arrêter
# Damsolitaire
# Dems
# C'est bon ?

# %%
def write_lyrics_to_file(artist_name, song_count, TOKEN = GENIUS_API_TOKEN):
    f = open('/content/drive/MyDrive/ProjetDL/lyrics/' + artist_name.lower() + '.txt', 'wb')
    urls = request_song_url(artist_name, song_count, TOKEN)
    for url in urls:
        lyrics = scrape_song_lyrics(url)
        f.write(lyrics.encode("utf8"))
    f.close()
    num_lines = sum(1 for line in open('/content/drive/MyDrive/ProjetDL/lyrics/' + artist_name.lower() + '.txt', 'rb'))
    print('Wrote {} lines to file from {} songs'.format(num_lines, song_count))

# DEMO  /content/drive/MyDrive/ProjetDL 
write_lyrics_to_file('Damso', 20, TOKEN = GENIUS_API_TOKEN_Etienne)
# Out:
# Found 20 songs by Damso
# Wrote 1455 lines to file from 20 songs

# %%
my_file = open("/content/drive/MyDrive/ProjetDL/artistes.txt", "r")
content = my_file.read()
artists_list = content.splitlines()
artists_list = [name.rstrip() for name in artists_list]
print(artists_list[400:])
# Out:
# ['Psy 4 de la rime', 'Psykick Lyrikah', 'Psykopat', 'Puzzle', 'Raggasonic', "Raï'n'B Fever", 'Rapsonic', 'Reciprok', 'Relic', 'Les Rieurs', 'La Rumeur', 'S-Crew', 'Sages Poètes de la rue', 'Saïan Supa Crew', 'Scred Connexion', 'Secteur Ä', 'Section Fu', "Sexion d'assaut", 'The Shin Sekaï', 'Shuffle', 'Silmarils', "L'Skadrille", 'Smokey Joe & The Kid', 'Sniper', 'Soul Swing', 'Les Spécialistes', 'Spoke Orkestra', 'Stupeflip', 'Suprême NTM', 'Svinkels', 'La Swija', 'Tandem', 'Team BS', 'Therapie Taxi', 'Time Bomb', 'TLF', 'Tout simplement noir', 'Tragédie', 'Tribal Jam', 'Triptik', 'TSR Crew', 'TTC', 'Under Kontrol', 'Unité 2 Feu', 'Les X', 'XVBarbar', "Zone d'expression populaire", 'Zweierpasch', '']

# %%
# write the lyrics file of each artist, by group of 100 or less (takes a lot of time as the API is not especially made to be scrapped ;) )

for rap_god in artists_list[200:299] :
    write_lyrics_to_file(rap_god, 300) # au plus 10 chansons par artistes pour tester
# Out:
# Found 231 songs by Niro
# Wrote 14138 lines to file from 300 songs
# Found 207 songs by Niska
# Wrote 9727 lines to file from 300 songs
# Found 103 songs by Nubi
# Wrote 7290 lines to file from 300 songs
# Found 50 songs by Oboy
# Wrote 2247 lines to file from 300 songs
# Found 4 songs by OGB
# Wrote 216 lines to file from 300 songs
# Found 0 songs by Ol Kainry
# Wrote 0 lines to file from 300 songs
# Found 86 songs by Orelsan
# Wrote 5725 lines to file from 300 songs
# Found 28 songs by Panama Bende
# Wrote 2940 lines to file from 300 songs
# Found 0 songs by Lucien Papalu
# Wrote 0 lines to file from 300 songs
# Found 4 songs by Passi
# Wrote 176 lines to file from 300 songs
# Found 0 songs by Benjamin Paulin
# Wrote 0 lines to file from 300 songs
# Found 24 songs by Al Peco
# Wrote 1217 lines to file from 300 songs
# Found 0 songs by Pih Poh
# Wrote 0 lines to file from 300 songs
# Found 32 songs by Piloophaz
# Wrote 1019 lines to file from 300 songs
# Found 0 songs by Pilote le Hot
# Wrote 0 lines to file from 300 songs
# Found 152 songs by PLK
# Wrote 7714 lines to file from 300 songs
# Found 35 songs by Eddy de Pretto
# Wrote 1625 lines to file from 300 songs
# Found 0 songs by Pro176
# Wrote 0 lines to file from 300 songs
# Found 201 songs by Oxmo Puccino
# Wrote 9952 lines to file from 300 songs
# Found 0 songs by Pyroman
# Wrote 0 lines to file from 300 songs
# Found 67 songs by Monsieur R
# Wrote 2590 lines to file from 300 songs
# Found 74 songs by Le Rat Luciano
# Wrote 3675 lines to file from 300 songs
# Found 2 songs by Rémy
# Wrote 139 lines to file from 300 songs
# Found 95 songs by Ridsa
# Wrote 6241 lines to file from 300 songs
# Found 69 songs by Rilès
# Wrote 4470 lines to file from 300 songs
# Found 0 songs by Rim'K
# Wrote 0 lines to file from 300 songs
# Found 37 songs by Riski
# Wrote 1518 lines to file from 300 songs
# Found 174 songs by RK
# Wrote 10709 lines to file from 300 songs
# Found 82 songs by Rocca
# Wrote 5684 lines to file from 300 songs
# Found 55 songs by Rocé
# Wrote 3242 lines to file from 300 songs
# Found 0 songs by Rockin' Squat
# Wrote 0 lines to file from 300 songs
# Found 300 songs by Rohff
# Wrote 25356 lines to file from 300 songs
# Found 26 songs by Rouda
# Wrote 1204 lines to file from 300 songs
# Found 46 songs by S-Pion
# Wrote 1943 lines to file from 300 songs
# Found 169 songs by Sadek
# Wrote 9959 lines to file from 300 songs
# Found 134 songs by Salif
# Wrote 7834 lines to file from 300 songs
# Found 32 songs by Sir Samuel
# Wrote 1129 lines to file from 300 songs
# Found 0 songs by Sat l'Artificier
# Wrote 0 lines to file from 300 songs
# Found 20 songs by Sauveur Eloheem
# Wrote 659 lines to file from 300 songs
# Found 36 songs by SCH
# Wrote 3220 lines to file from 300 songs
# Found 83 songs by Sefyu
# Wrote 5446 lines to file from 300 songs
# Found 124 songs by Sheek
# Wrote 6973 lines to file from 300 songs
# Found 0 songs by Shone d'Holocost
# Wrote 0 lines to file from 300 songs
# Found 0 songs by Shurik'n
# Wrote 0 lines to file from 300 songs
# Found 55 songs by Siboy
# Wrote 2986 lines to file from 300 songs
# Found 204 songs by Sinik
# Wrote 13165 lines to file from 300 songs
# Found 4 songs by Six
# Wrote 449 lines to file from 300 songs
# Found 0 songs by Smartzee
# Wrote 0 lines to file from 300 songs
# Found 89 songs by Sneazzy
# Wrote 6186 lines to file from 300 songs
# Found 0 songs by Solo
# Wrote 0 lines to file from 300 songs
# Found 6 songs by Soon E MC
# Wrote 343 lines to file from 300 songs
# Found 215 songs by Soprano
# Wrote 12924 lines to file from 300 songs
# Found 59 songs by Soso Maness
# Wrote 2719 lines to file from 300 songs
# Found 107 songs by S.Pri Noir
# Wrote 5910 lines to file from 300 songs
# Found 90 songs by Still Fresh
# Wrote 5256 lines to file from 300 songs
# Found 32 songs by Stomy Bugsy
# Wrote 2099 lines to file from 300 songs
# Found 0 songs by Styck
# Wrote 0 lines to file from 300 songs
# Found 95 songs by Sultan
# Wrote 5277 lines to file from 300 songs
# Found 29 songs by Swagg Man
# Wrote 1605 lines to file from 300 songs
# Found 45 songs by Iron Sy
# Wrote 1188 lines to file from 300 songs
# Found 0 songs by Faouzi Tarkhani
# Wrote 0 lines to file from 300 songs
# Found 14 songs by Teki Latex
# Wrote 647 lines to file from 300 songs
# Found 2 songs by Tepa
# Wrote 121 lines to file from 300 songs
# Found 14 songs by Tepr
# Wrote 57 lines to file from 300 songs
# Found 113 songs by Timal
# Wrote 4609 lines to file from 300 songs
# Found 56 songs by TLF
# Wrote 4006 lines to file from 300 songs
# Found 1 songs by Martial Tricoche
# Wrote 51 lines to file from 300 songs
# Found 78 songs by Tsew The Kid
# Wrote 2756 lines to file from 300 songs
# Found 49 songs by Tunisiano
# Wrote 3552 lines to file from 300 songs
# Found 60 songs by Usky
# Wrote 1988 lines to file from 300 songs
# Found 49 songs by Lorca
# Wrote 2867 lines to file from 300 songs
# Found 2 songs by Vald
# Wrote 200 lines to file from 300 songs
# Found 17 songs by Vicelow
# Wrote 1074 lines to file from 300 songs
# Found 6 songs by Vincha
# Wrote 335 lines to file from 300 songs
# Found 0 songs by Vîrus
# Wrote 0 lines to file from 300 songs
# Found 54 songs by Wacko
# Wrote 2322 lines to file from 300 songs
# Found 95 songs by Alpha Wann
# Wrote 6094 lines to file from 300 songs
# Found 0 songs by Sulee B Wax
# Wrote 0 lines to file from 300 songs
# Found 171 songs by Yannick
# Wrote 6260 lines to file from 300 songs
# Found 0 songs by Yosoji
# Wrote 0 lines to file from 300 songs
# Found 0 songs by Michaël Youn
# Wrote 0 lines to file from 300 songs
# Found 12 songs by Young Chang Mc
# Wrote 872 lines to file from 300 songs
# Found 162 songs by Youssoupha
# Wrote 9518 lines to file from 300 songs
# Found 71 songs by Youv Dee
# Wrote 4530 lines to file from 300 songs
# Found 0 songs by Jean-Pascal Zadi
# Wrote 0 lines to file from 300 songs
# Found 0 songs by Sofiane Zermani
# Wrote 0 lines to file from 300 songs
# Found 49 songs by Zesau
# Wrote 2985 lines to file from 300 songs
# Found 39 songs by Darryl Zeuja
# Wrote 1731 lines to file from 300 songs
# Found 46 songs by Zola
# Wrote 2494 lines to file from 300 songs
# Found 43 songs by Zoxea
# Wrote 2556 lines to file from 300 songs
# Found 4 songs by 2 Bal
# Wrote 291 lines to file from 300 songs
# Found 0 songs by 3e Œil
# Wrote 0 lines to file from 300 songs
# Found 150 songs by 4Keus
# Wrote 10373 lines to file from 300 songs
# Found 19 songs by 5 majeur
# Wrote 1725 lines to file from 300 songs
# Found 112 songs by 13 Block
# Wrote 7483 lines to file from 300 songs
# Found 1 songs by 92i
# Wrote 76 lines to file from 300 songs
# Found 98 songs by 113
# Wrote 6408 lines to file from 300 songs
# Found 0 songs by 400 Hyènes
# Wrote 0 lines to file from 300 songs
# Found 38 songs by 1995
# Wrote 3110 lines to file from 300 songs
